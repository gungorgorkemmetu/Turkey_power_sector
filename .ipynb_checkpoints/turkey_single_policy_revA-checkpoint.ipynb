# %% [markdown]
# # Turkish power sector Tutorial Part 3: A Policy Scenario
#
# This tutorial is based on the [Austria Energy System](https://docs.messageix.org/en/stable/tutorials.html#austrian-energy-system) tutorial of *MESSAGEix*.
#
# **Pre-requisites**
# - You have the *MESSAGEix* framework installed and working
# - You have run Turkish energy system baseline scenario (``turkey_revA.ipynb``) and solved it successfully
#
# **Introduction**
#
# In this notebook, we will step through creating and investigating a policy scenario.
#
# We will look into the effect of wind generation subsidies on the electricity sector. These subsidies will take the form of capital investment subsidies, effectively reducing the costs of capital investment.

# %% [markdown]
# # Setup and Helper Variables

# %%
# load required packages 
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import ixmp as ix
import message_ix

# %%
# launch the IX modeling platform using the local default database
mp = ix.Platform(name="local")
# Out:
# 2026-03-24 20:32:45,306  INFO at.ac.iiasa.ixmp.Platform:165 - Welcome to the IX modeling platform!
# 2026-03-24 20:32:45,417  INFO at.ac.iiasa.ixmp.Platform:166 -  connected to database 'jdbc:hsqldb:file:/home/ggungor/.local/share/ixmp/localdb/default' (user: ixmp)...

# %%
country = 'Turkey'

plants = [
    "lignite_ppl",
    "hardcoal_ppl", 
    "gas_ppl", 
    "oil_ppl", 
    "bio_ppl", 
    "hydro_ppl",
    "wind_ppl", 
    "geothermal",
    "solar_pv_ppl",
]

lights = [
    "low_efficiency", 
    "high_efficiency", 
]

# %% [markdown]
# # Create the New Policy Scenario Datastructure
#
# This operation is done by cloning the baseline scenario, which will then be edited.

# %%
scen_df = mp.scenario_list() # to find the name of the wanted scenario, simply print scen_df
scen_df.loc[scen_df["scenario"] == "baseline"] # to show just the scenario we are interested in
# Out:
#                   model  scenario   scheme  is_default  is_locked cre_user  \
# 0   Turkey energy model  baseline  MESSAGE           1          0  ggungor
# 1  Westeros Electrified  baseline  MESSAGE           1          0  ggungor
#
#                      cre_date upd_user                    upd_date lock_user  \
# 0  2026-03-24 20:29:32.624000  ggungor  2026-03-24 20:30:03.749000      None
# 1  2026-03-22 13:50:44.368000  ggungor  2026-03-22 13:51:11.763000      None
#
#   lock_date                                annotation  version
# 0      None           initial commit for Turkey model        4
# 1      None  basic model of Westerosi electrification        1

# %%
model = "Turkey energy model"
scen = "baseline"
mp.open_db() # only open if you're on a local database!
base = message_ix.Scenario(mp, model, scen)
scenario = base.clone(model, 'solar subsidies', 'testing solar subsidies', keep_solution=False)
scenario.check_out()

# %%
mp.scenario_list()
# Out:
#                   model         scenario   scheme  is_default  is_locked  \
# 0   Turkey energy model         baseline  MESSAGE           1          0
# 1   Turkey energy model  solar subsidies  MESSAGE           1          1
# 2  Westeros Electrified         baseline  MESSAGE           1          0
#
#   cre_user                    cre_date upd_user                    upd_date  \
# 0  ggungor  2026-03-24 20:29:32.624000  ggungor  2026-03-24 20:30:03.749000
# 1  ggungor  2026-03-24 20:34:32.641000     None                        None
# 2  ggungor  2026-03-22 13:50:44.368000  ggungor  2026-03-22 13:51:11.763000
#
#   lock_user                   lock_date  \
# 0      None                        None
# 1   ggungor  2026-03-24 20:34:43.504000
# 2      None                        None
#
#                                           annotation  version
# 0                    initial commit for Turkey model        4
# 1  clone Scenario from 'Turkey energy model|basel...        1
# 2           basic model of Westerosi electrification        1

# %%
horizon = scenario.set('year')

# %% [markdown]
# # Edit the Datastructure with the Scenario Parameters
#
# Introduce subsidies that decay with time. Initially they are 75% of the total investment costs and decay to 0.

# %%
inv_cost_df = scenario.par('inv_cost')
inv_cost_df.loc[inv_cost_df["technology"] == "solar_pv_ppl"]
# Out:
#    node_loc    technology  year_vtg   value    unit
# 56   Turkey  solar_pv_ppl      2020  1025.0  USD/kW
# 57   Turkey  solar_pv_ppl      2025  1025.0  USD/kW
# 58   Turkey  solar_pv_ppl      2030  1025.0  USD/kW
# 59   Turkey  solar_pv_ppl      2035  1025.0  USD/kW
# 60   Turkey  solar_pv_ppl      2040  1025.0  USD/kW
# 61   Turkey  solar_pv_ppl      2045  1025.0  USD/kW
# 62   Turkey  solar_pv_ppl      2050  1025.0  USD/kW

# %%
subsidies = np.array([0.25, 0.25, 0.25, 0.5, 0.5, 0.75, 1])
inv_cost = pd.DataFrame({
        'node_loc': country,
        'year_vtg': horizon,
        'technology': 'solar_pv_ppl',
        'value': 1025 * subsidies,
        'unit': 'USD/kW',
})
scenario.add_par('inv_cost', inv_cost)

# %%
scenario.par("inv_cost").loc[inv_cost_df["technology"] == "solar_pv_ppl"]
# Out:
#    node_loc    technology  year_vtg    value    unit
# 56   Turkey  solar_pv_ppl      2020   256.25  USD/kW
# 57   Turkey  solar_pv_ppl      2025   256.25  USD/kW
# 58   Turkey  solar_pv_ppl      2030   256.25  USD/kW
# 59   Turkey  solar_pv_ppl      2035   512.50  USD/kW
# 60   Turkey  solar_pv_ppl      2040   512.50  USD/kW
# 61   Turkey  solar_pv_ppl      2045   768.75  USD/kW
# 62   Turkey  solar_pv_ppl      2050  1025.00  USD/kW

# %% [markdown]
# # Solve the Model

# %%
scenario.commit('solar subsidies added')
scenario.set_as_default()

# %%
scenario.solve()
# Out:
# --- Warning: The GAMS version [51.3.0] differs from the API version [24.8.3].
# --- Job MESSAGE_run.gms Start 03/24/26 20:38:51 51.3.0 38407a9b LEX-LEG x86 64bit/Linux
# --- Applying:
#     /home/ggungor/Downloads/gams51.3_linux_x64_64_sfx/gmsprmun.txt
# --- GAMS Parameters defined
#     Input /home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/MESSAGE_run.gms
#     ScrDir /home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/225a/
#     SysDir /home/ggungor/Downloads/gams51.3_linux_x64_64_sfx/
#     LogOption 4
#     LogFile /home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/MESSAGE_run.log
#     AppendLog 1
#     --in /home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_solar_subsidies.gdx
#     --out /home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/output/MsgOutput_Turkey_energy_model_solar_subsidies.gdx
#     --iter /home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/output/MsgIterationReport_Turkey_energy_model_solar_subsidies.gdx
# Licensee: G?rkem G?ng?r                                  G260118+0003Ac-GEN
#           ggungor@mezun.hacettepe.edu.tr                          CLA115848
#           /home/ggungor/Downloads/gams51.3_linux_x64_64_sfx/gamslice.txt
#           node:60351003 v:2
#           Community license for demonstration and instructional purposes only
# System information: 2 physical cores and 4 Gb physical memory detected
# GAMS 51.3.0   Copyright (C) 1987-2025 GAMS Development. All rights reserved
# --- Starting compilation
# --- MESSAGE_run.gms(3) 2 Mb
# --- . copyright.gms(29) 2 Mb
# --- MESSAGE_run.gms(30) 2 Mb
# --- . model_setup.gms(66) 2 Mb
# --- .. auxiliary_settings.gms(37) 2 Mb
# --- . model_setup.gms(69) 2 Mb
# --- .. version.gms(23) 2 Mb
# --- . model_setup.gms(70) 2 Mb
# --- .. version_check.gms(7) 2 Mb
# --- GDXin=/home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_solar_subsidies.gdx
# --- GDX File ($gdxIn) /home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_solar_subsidies.gdx
# --- .. version_check.gms(24) 3 Mb
# --- . model_setup.gms(73) 3 Mb
# --- .. sets_maps_def.gms(511) 3 Mb
# --- . model_setup.gms(74) 3 Mb
# --- .. parameter_def.gms(907) 3 Mb
# --- . model_setup.gms(77) 3 Mb
# --- .. data_load.gms(9) 3 Mb
# --- GDXin=/home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_solar_subsidies.gdx
# --- GDX File ($gdxIn) /home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_solar_subsidies.gdx
# --- .. data_load.gms(126) 3 Mb
# --- ... period_parameter_assignment.gms(118) 3 Mb
# --- .. data_load.gms(269) 3 Mb
# --- . model_setup.gms(80) 3 Mb
# --- .. scaling_investment_costs.gms(182) 3 Mb
# --- . model_setup.gms(86) 3 Mb
# --- .. model_core.gms(2339) 3 Mb
# --- . model_setup.gms(86) 3 Mb
# --- MESSAGE_run.gms(36) 3 Mb
# --- . model_solve.gms(109) 3 Mb
# --- .. aux_computation_time.gms(14) 3 Mb
# --- . model_solve.gms(175) 3 Mb
# --- MESSAGE_run.gms(43) 3 Mb
# --- . reporting.gms(26) 3 Mb
# --- MESSAGE_run.gms(52) 3 Mb
# --- Starting execution: elapsed 0:00:00.229
# --- MESSAGE_run.gms(1644) 4 Mb
#     +++ Importing data from '/home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_solar_subsidies.gdx'... +++
# --- MESSAGE_run.gms(1669) 4 Mb
# --- GDXin=/home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_solar_subsidies.gdx
# --- GDX File (execute_load) /home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_solar_subsidies.gdx
# --- MESSAGE_run.gms(4570) 4 Mb
#     +++ Solve the perfect-foresight version of MESSAGEix +++
# --- Generating LP model MESSAGE_LP
# --- MESSAGE_run.gms(4588) 5 Mb
# ---   766 rows  621 columns  2,675 non-zeroes
# --- Range statistics (absolute non-zero finite values)
# --- RHS       [min, max] : [ 8.037E-02, 4.462E+01] - Zero values observed as well
# --- Bound     [min, max] : [        NA,        NA] - Zero values observed as well
# --- Matrix    [min, max] : [ 1.000E-01, 3.100E+03]
# --- Executing CPLEX (Solvelink=2): elapsed 0:00:00.348
#
# IBM ILOG CPLEX   51.3.0 38407a9b Oct 27, 2025          LEG x86 64bit/Linux
#
# *** This solver runs with a community license. No commercial use.
#
# Reading parameter(s) from "/home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/cplex.opt"
# >>  advind = 0
# >>  lpmethod = 4
# >>  threads = 4
# >>  epopt = 1e-06
# Finished reading from "/home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 0.07 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 0.66 Mb (peak 0.66 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 22.1.2.0 link memory 0.02 Mb (peak 0.14 Mb)
# --- Starting Cplex
#
# Version identifier: 22.1.2.0 | 2024-11-26 | 0edbb82fd
# CPXPARAM_Advance                                 0
# CPXPARAM_LPMethod                                4
# CPXPARAM_Threads                                 4
# CPXPARAM_Parallel                                1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_Barrier_Limits_Iteration                100000000
# CPXPARAM_TimeLimit                               1000000
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   0
# Tried aggregator 1 time.
# LP Presolve eliminated 302 rows and 170 columns.
# Aggregator did 108 substitutions.
# Reduced LP has 355 rows, 388 columns, and 1277 nonzeros.
# Presolve time = 0.05 sec. (0.95 ticks)
# Parallel mode: using up to 4 threads for barrier.
# Number of nonzeros in lower triangle of A*A' = 1164
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.19 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 4
#   Rows in Factor            = 355
#   Integer space required    = 775
#   Total non-zeros in factor = 4275
#   Total FP ops to factor    = 61271
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf Inf Ratio
#    0   1.6643520e+06   1.2821262e+05  6.95e+03  5.41e+01  2.07e+05  1.00e+00
#    1   1.0116010e+06   2.7184938e+05  3.55e+03  2.77e+01  5.86e+04  1.43e-03
#    2   6.6633887e+05   3.3436596e+05  1.71e+03  1.33e+01  9.42e+03  2.88e-03
#    3   5.1076590e+05   3.6535183e+05  7.78e+02  6.06e+00  3.16e+03  5.27e-03
#    4   4.4711230e+05   3.7774604e+05  3.58e+02  2.79e+00  1.74e+03  8.14e-03
#    5   4.2101774e+05   3.8992416e+05  1.74e+02  1.35e+00  6.05e+02  2.27e-02
#    6   4.0833666e+05   3.9345132e+05  7.71e+01  6.00e-01  3.48e+02  3.34e-02
#    7   4.0149228e+05   3.9742614e+05  2.36e+01  1.83e-01  7.31e+01  1.62e-01
#    8   3.9956097e+05   3.9804510e+05  7.54e+00  5.86e-02  3.62e+01  3.18e-01
#    9   3.9891403e+05   3.9855185e+05  1.97e+00  1.53e-02  7.54e+00  1.53e+00
#   10   3.9871470e+05   3.9865347e+05  2.11e-01  1.64e-03  2.02e+00  5.67e+00
#   11   3.9869689e+05   3.9868691e+05  5.75e-02  4.47e-04  1.82e-01  6.66e+01
#   12   3.9869097e+05   3.9868917e+05  9.84e-03  7.66e-05  3.75e-02  2.65e+02
#   13   3.9869010e+05   3.9868992e+05  1.60e-03  1.25e-05  3.39e-04  2.91e+04
#   14   3.9868996e+05   3.9868991e+05  3.98e-04  3.09e-06  8.45e-05  9.00e+03
#   15   3.9868994e+05   3.9868994e+05  1.48e-06  1.15e-08  3.55e-08  6.77e+07
#   16   3.9868994e+05   3.9868994e+05  5.32e-08  1.53e-12  1.03e-07  3.39e+10
# Barrier time = 0.13 sec. (2.82 ticks)
# Parallel mode: deterministic, using up to 4 threads for concurrent optimization:
#  * Starting dual Simplex on 1 thread...
#  * Starting primal Simplex on 1 thread...
#
# Dual crossover.
#   Dual:  Fixing 134 variables.
#       133 DMoves:  Infeasibility  0.00000000e+00  Objective  3.98689939e+05
#        50 DMoves:  Infeasibility  0.00000000e+00  Objective  3.98689939e+05
#         0 DMoves:  Infeasibility  0.00000000e+00  Objective  3.98689939e+05
#   Dual:  Pushed 10, exchanged 124.
#   Primal:  Fixed no variables.
#
# Dual simplex solved model.
#
# Total crossover time = 0.05 sec. (0.99 ticks)
#
# Total time on 4 threads = 0.24 sec. (4.78 ticks)
#
# --- LP status (1): optimal.
# --- Cplex Time: 0.27sec (det. 4.79 ticks)
#
#
# Optimal solution found
# Objective:       398689.938804
#
# --- Reading solution for model MESSAGE_LP
# --- Executing after solve: elapsed 0:00:01.479
# --- MESSAGE_run.gms(4786) 5 Mb
# --- GDX File (execute_unload) /home/ggungor/miniconda3/lib/python3.12/site-packages/message_ix/model/output/MsgOutput_Turkey_energy_model_solar_subsidies.gdx
# --- MESSAGE_run.gms(4788) 5 Mb
#     +++ End of MESSAGEix (stand-alone) run - have a nice day! +++
# *** Status: Normal completion
# --- Job MESSAGE_run.gms Stop 03/24/26 20:38:53 elapsed 0:00:01.514
# --- Warning: The GAMS version [51.3.0] differs from the API version [24.8.3].
# --- Warning: The GAMS version [51.3.0] differs from the API version [24.8.3].
# 2026-03-24 20:38:53,812 ERROR at.ac.iiasa.ixmp.objects.Scenario:1691 - variable 'I' not found in gdx!
# 2026-03-24 20:38:53,840 ERROR at.ac.iiasa.ixmp.objects.Scenario:1691 - variable 'C' not found in gdx!

# %%
scenario.var('OBJ')['lvl']
# Out:
# 398689.9375

# %% [markdown]
# # Investigate the Results

# %%
from message_ix.reporting import Reporter
from message_ix.util.tutorial import prepare_plots

config = dict(filters=dict(t=plants))
base_rep = Reporter.from_scenario(base, **config)
prepare_plots(base_rep)
scen_rep = Reporter.from_scenario(scenario, **config)
prepare_plots(scen_rep)
# Out:
# /tmp/ipykernel_5221/1802225191.py:1: DeprecationWarning: Importing from 'message_ix.reporting' is deprecated and will fail in a future version. Use 'message_ix.report'.
#   from message_ix.reporting import Reporter
# Cannot redefine 'y' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)

# %%
base_rep.get("plot new capacity")
scen_rep.get("plot new capacity")
# Out:
# <Axes: title={'center': 'Turkey Energy System New Capacity'}, xlabel='Year', ylabel='GWa'>

# %%
base_rep.get("plot capacity")
scen_rep.get("plot capacity")
# Out:
# <Axes: title={'center': 'Turkey Energy System Capacity'}, xlabel='Year', ylabel='GW'>

# %%
base_rep.get("plot activity")
scen_rep.get("plot activity")
# Out:
# <Axes: title={'center': 'Turkey Energy System Activity'}, xlabel='Year', ylabel='GWa'>

# %%
mp.close_db()
