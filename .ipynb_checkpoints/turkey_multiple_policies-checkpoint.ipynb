# %% [markdown]
# # Turkish power sector Tutorial Part 4: Investigating Many Policy Scenarios
#
# **Pre-requisites**
# - You have the *MESSAGEix* framework installed and working
# - You have run Turkish power sector baseline scenario (`turkey_revA.ipynb`) and solved it successfully
# - You have completed the tutorial on introducing one policy scenario (`turkey_single_policy_revA.ipynb`)
#
# **Introduction**
#
# In this notebook, we investigate a number of different scenarios.
# This process is streamlined with the utility function `solve_modified()`, used in a Python `with:` statement:
#
# ```python
# with solve_modified(base_scenario, new_name) as scen:
#    # (`scen` is automatically cloned from `base_scenario` with name `new_name`)
#
#    # Your code to modify `scen` <---
#
#    # (`scen` is automatically committed with modifications, then solved)
#
# # Your code to investigate the solution of `scen` <---
# ```
#
# All of the cloning, committing, and solving actions are handled for you.
# Your job is to concentrate on identifying and updating the scenario variables and then investigating the results.
#
# You can, of course, get the `Scenario` as you have worked on previously as well.

# %% [markdown]
# ## Setup and Helper Variables

# %%
# Load required packages 
import numpy as np
import pandas as pd

from matplotlib.pyplot import style
import matplotlib_inline

import ixmp as ix
import message_ix
from message_ix.reporting import Reporter
from message_ix.util.tutorial import prepare_plots, solve_modified
# from message_ix.testing import make_austria

# Appearance of plots
# %matplotlib inline
matplotlib_inline.backend_inline.set_matplotlib_formats("svg")
style.use("ggplot")
# Out:
# /tmp/ipykernel_6462/1269771928.py:10: DeprecationWarning: Importing from 'message_ix.reporting' is deprecated and will fail in a future version. Use 'message_ix.report'.
#   from message_ix.reporting import Reporter
# Cannot redefine 'y' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)

# %%
# launch the IX modeling platform using the local default database                                                                                                                       
mp = ix.Platform(name="default", jvmargs="-Duser.language=en")
# Out:
# 2025-05-04 11:50:02,163  INFO at.ac.iiasa.ixmp.Platform:165 - Welcome to the IX modeling platform!
# 2025-05-04 11:50:02,167  INFO at.ac.iiasa.ixmp.Platform:166 -  connected to database 'jdbc:hsqldb:file:/home/ggungor/.local/share/ixmp/localdb/default' (user: ixmp)...

# %%
country = "Turkey"
horizon = range(2020, 2051, 5)

plants = [
    "bio_ppl", 
    "coal_ppl", 
    "gas_ppl", 
    "oil_ppl", 
    "hydro_ppl",
    "solar_pv_ppl",
    "wind_ppl",
    "geothermal",
]

light_and_appliance = ["low_efficiency", "high_efficiency"]

# %%
# Create the baseline scenario and solve it
# base_scen = make_austria(mp, solve=True)
model = "Turkey energy model"
scen = "baseline"
base_scen = message_ix.Scenario(mp, model, scen)

# Create a reporter with tutorial plots
base_rep = Reporter.from_scenario(base_scen)
prepare_plots(base_rep)

# %%
base_rep.set_filters(t=plants)
base_rep.get("plot activity")
# Out:
# <Axes: title={'center': 'Turkey Energy System Activity'}, xlabel='Year', ylabel='GWa'>

# %%
emissions = {
    'coal_ppl': ('CO2', 0.854), # units: tCO2/MWh
    'gas_ppl':  ('CO2', 0.339), # units: tCO2/MWh
    'oil_ppl':  ('CO2', 0.57),  # units: tCO2/MWh
}

# %% [markdown]
# # Wind Subsidies
#
# Rerun the wind subsidy scenario using this framework.

# %%
# Percent subsidy by year
subsidies = np.array([0.75, 0.75, 0.75, 0.5, 0.5, 0.5, 0.25])

with solve_modified(base_scen, new_name="wind_subsidies") as wind_scen:
    # Load the investment cost data (cloned from `base_scen`) for wind_ppl
    data = wind_scen.par("inv_cost", filters=dict(technology="wind_ppl"))
    
    # Reduce the values according to the subsidy
    data["value"] = data["value"] * (1 - subsidies) * 0.5
    
    # Overwrite the values in `wind_scen` at the same indices
    wind_scen.add_par("inv_cost", data)
    
# Display the new costs
data
# Out:
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# --- Job MESSAGE_run.gms Start 05/04/25 11:57:58 48.5.0 5f05ac2f LEX-LEG x86 64bit/Linux
# --- Applying:
#     /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/gmsprmun.txt
# --- GAMS Parameters defined
#     Input /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/MESSAGE_run.gms
#     ScrDir /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/225a/
#     SysDir /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/
#     LogOption 4
#     --in /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_wind_subsidies.gdx
#     --out /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgOutput_Turkey_energy_model_wind_subsidies.gdx
#     --iter /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgIterationReport_Turkey_energy_model_wind_subsidies.gdx
# Licensee: G?rkem G?ng?r                                  G250104+0003Ac-GEN
#           ggungor@mezun.hacettepe.edu.tr                          CLA105467
#           /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/gamslice.txt
#           node:15017401 v:2
#           Community license for demonstration and instructional purposes only
# Processor information: 1 socket(s), 2 core(s), and 2 thread(s) available
# GAMS 48.5.0   Copyright (C) 1987-2024 GAMS Development. All rights reserved
# --- Starting compilation
# --- MESSAGE_run.gms(65) 2 Mb
# --- . model_setup.gms(66) 2 Mb
# --- .. auxiliary_settings.gms(37) 2 Mb
# --- . model_setup.gms(69) 2 Mb
# --- .. version.gms(23) 2 Mb
# --- . model_setup.gms(70) 2 Mb
# --- .. version_check.gms(7) 2 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_wind_subsidies.gdx
# --- GDX File ($gdxIn) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_wind_subsidies.gdx
# --- .. version_check.gms(24) 3 Mb
# --- . model_setup.gms(73) 3 Mb
# --- .. sets_maps_def.gms(490) 3 Mb
# --- . model_setup.gms(74) 3 Mb
# --- .. parameter_def.gms(878) 3 Mb
# --- . model_setup.gms(77) 3 Mb
# --- .. data_load.gms(9) 3 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_wind_subsidies.gdx
# --- GDX File ($gdxIn) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_wind_subsidies.gdx
# --- .. data_load.gms(111) 3 Mb
# --- ... period_parameter_assignment.gms(118) 3 Mb
# --- .. data_load.gms(252) 3 Mb
# --- . model_setup.gms(80) 3 Mb
# --- .. scaling_investment_costs.gms(182) 3 Mb
# --- . model_setup.gms(86) 3 Mb
# --- .. model_core.gms(2311) 3 Mb
# --- . model_setup.gms(86) 3 Mb
# --- MESSAGE_run.gms(71) 3 Mb
# --- . model_solve.gms(104) 3 Mb
# --- .. aux_computation_time.gms(14) 3 Mb
# --- . model_solve.gms(170) 3 Mb
# --- MESSAGE_run.gms(78) 3 Mb
# --- . reporting.gms(26) 3 Mb
# --- MESSAGE_run.gms(87) 3 Mb
# --- Starting execution: elapsed 0:00:00.042
# --- MESSAGE_run.gms(1600) 4 Mb
#     +++ Importing data from '/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_wind_subsidies.gdx'... +++
# --- MESSAGE_run.gms(1625) 4 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_wind_subsidies.gdx
# --- GDX File (execute_load) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_wind_subsidies.gdx
# --- MESSAGE_run.gms(4481) 4 Mb
#     +++ Solve the perfect-foresight version of MESSAGEix +++
# --- Generating LP model MESSAGE_LP
# --- MESSAGE_run.gms(4499) 5 Mb
# ---   691 rows  566 columns  2,350 non-zeroes
# --- Range statistics (absolute non-zero finite values)
# --- RHS       [min, max] : [ 3.687E-02, 4.450E+01] - Zero values observed as well
# --- Bound     [min, max] : [        NA,        NA] - Zero values observed as well
# --- Matrix    [min, max] : [ 1.000E-01, 4.017E+03]
# --- Executing CPLEX (Solvelink=2): elapsed 0:00:00.053
#
# IBM ILOG CPLEX   48.5.0 5f05ac2f Dec 20, 2024          LEG x86 64bit/Linux
#
# *** This solver runs with a community license. No commercial use.
#
# Reading parameter(s) from "/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/cplex.opt"
# >>  advind = 0
# >>  lpmethod = 4
# >>  threads = 4
# >>  epopt = 1e-06
# Finished reading from "/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 0.06 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 0.64 Mb (peak 0.65 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 22.1.1.0 link memory 0.02 Mb (peak 0.12 Mb)
# --- Starting Cplex
#
# Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_Advance                                 0
# CPXPARAM_LPMethod                                4
# CPXPARAM_Threads                                 4
# CPXPARAM_Parallel                                1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_Barrier_Limits_Iteration                100000000
# CPXPARAM_TimeLimit                               1000000
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   0
# Tried aggregator 1 time.
# LP Presolve eliminated 245 rows and 133 columns.
# Aggregator did 107 substitutions.
# Reduced LP has 338 rows, 371 columns, and 1197 nonzeros.
# Presolve time = 0.00 sec. (0.85 ticks)
# Parallel mode: using up to 4 threads for barrier.
# Number of nonzeros in lower triangle of A*A' = 1087
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.17 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 4
#   Rows in Factor            = 338
#   Integer space required    = 737
#   Total non-zeros in factor = 4033
#   Total FP ops to factor    = 57527
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf Inf Ratio
#    0   2.7041598e+06   2.6059742e+05  7.80e+03  1.14e+02  4.80e+03  1.00e+00
#    1   2.2891564e+06   2.6190843e+05  6.48e+03  9.46e+01  2.50e+03  1.59e-03
#    2   1.6919778e+06   2.7963481e+05  4.53e+03  6.62e+01  1.47e+03  1.31e-03
#    3   1.2678216e+06   3.2632228e+05  3.02e+03  4.41e+01  9.81e+02  1.30e-03
#    4   7.9808805e+05   3.4276057e+05  1.39e+03  2.03e+01  7.57e+02  1.43e-03
#    5   6.0945304e+05   3.8311512e+05  7.36e+02  1.07e+01  1.96e+02  4.03e-03
#    6   5.1489005e+05   4.0616694e+05  3.76e+02  5.49e+00  5.90e+01  1.05e-02
#    7   4.6403511e+05   4.1303600e+05  1.74e+02  2.54e+00  3.03e+01  1.99e-02
#    8   4.3368188e+05   4.1852375e+05  5.04e+01  7.37e-01  1.01e+01  4.76e-02
#    9   4.2509070e+05   4.2037415e+05  1.31e+01  1.91e-01  4.86e+00  8.62e-02
#   10   4.2264635e+05   4.2190982e+05  1.16e+00  1.70e-02  1.19e+00  3.59e-01
#   11   4.2239086e+05   4.2231911e+05  3.82e-02  5.58e-04  1.59e-01  3.02e+00
#   12   4.2237545e+05   4.2237370e+05  2.44e-03  3.57e-05  2.01e-03  2.55e+02
#   13   4.2237440e+05   4.2237439e+05  6.42e-07  9.37e-09  1.45e-06  3.86e+05
#   14   4.2237439e+05   4.2237439e+05  1.26e-10  1.27e-12  2.67e-10  5.39e+09
# Barrier time = 0.02 sec. (2.37 ticks)
# Parallel mode: deterministic, using up to 4 threads for concurrent optimization:
#  * Starting dual Simplex on 1 thread...
#  * Starting primal Simplex on 1 thread...
#
# Dual crossover.
#   Dual:  Fixing 166 variables.
#       165 DMoves:  Infeasibility  0.00000000e+00  Objective  4.22374395e+05
#        50 DMoves:  Infeasibility  0.00000000e+00  Objective  4.22374395e+05
#         0 DMoves:  Infeasibility  0.00000000e+00  Objective  4.22374395e+05
#   Dual:  Pushed 31, exchanged 135.
#   Primal:  Fixed no variables.
#
# Dual simplex solved model.
#
# Total crossover time = 0.00 sec. (0.89 ticks)
#
# Total time on 4 threads = 0.02 sec. (4.14 ticks)
#
# --- LP status (1): optimal.
# --- Cplex Time: 0.02sec (det. 4.14 ticks)
#
#
# Optimal solution found
# Objective:       422374.394757
#
# --- Reading solution for model MESSAGE_LP
# --- Executing after solve: elapsed 0:00:00.098
# --- MESSAGE_run.gms(4692) 5 Mb
# --- GDX File (execute_unload) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgOutput_Turkey_energy_model_wind_subsidies.gdx
# --- MESSAGE_run.gms(4694) 5 Mb
#     +++ End of MESSAGEix (stand-alone) run - have a nice day! +++
# *** Status: Normal completion
# --- Job MESSAGE_run.gms Stop 05/04/25 11:57:58 elapsed 0:00:00.101
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# 2025-05-04 11:57:59,135 ERROR at.ac.iiasa.ixmp.objects.Scenario:1691 - variable 'I' not found in gdx!
# 2025-05-04 11:57:59,137 ERROR at.ac.iiasa.ixmp.objects.Scenario:1691 - variable 'C' not found in gdx!
#   node_loc technology  year_vtg   value    unit
# 0   Turkey   wind_ppl      2020  186.25  USD/kW
# 1   Turkey   wind_ppl      2025  186.25  USD/kW
# 2   Turkey   wind_ppl      2030  186.25  USD/kW
# 3   Turkey   wind_ppl      2035  372.50  USD/kW
# 4   Turkey   wind_ppl      2040  372.50  USD/kW
# 5   Turkey   wind_ppl      2045  372.50  USD/kW
# 6   Turkey   wind_ppl      2050  558.75  USD/kW

# %%
# Prepare a Reporter based on the solved scenario
wind_rep = Reporter.from_scenario(wind_scen)
prepare_plots(wind_rep)

# Run the same reporting on both the base and modified scenarios
for r in base_rep, wind_rep:
    r.set_filters(t=plants)
    r.get("plot new capacity")

# %% [markdown]
# # Demand-Side Learning
#
# This model does not use `cfl`s in the baseline because they are too expensive. What happens if their cost reduces with time?

# %%
# Cost as a fraction of the baseline cost, due to learning
learning = np.array([1.0, 0.8, 0.6, 0.4, 0.2, 0.1, 0.1])

with solve_modified(base_scen, new_name="cheap_cfls") as cfl_scen:
    # Load the investment cost data (cloned from `base_scen`) for cfl
    data = cfl_scen.par("inv_cost", filters=dict(technology="high_efficiency"))
    
    # Reduce the values according to the learning curve
    data["value"] = data["value"] * learning
    
    # Overwrite the values in `cfl_scen` at the same indices
    cfl_scen.add_par("inv_cost", data)

# Display the new costs
data
# Out:
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# --- Job MESSAGE_run.gms Start 05/04/25 11:58:41 48.5.0 5f05ac2f LEX-LEG x86 64bit/Linux
# --- Applying:
#     /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/gmsprmun.txt
# --- GAMS Parameters defined
#     Input /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/MESSAGE_run.gms
#     ScrDir /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/225a/
#     SysDir /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/
#     LogOption 4
#     --in /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_cheap_cfls.gdx
#     --out /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgOutput_Turkey_energy_model_cheap_cfls.gdx
#     --iter /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgIterationReport_Turkey_energy_model_cheap_cfls.gdx
# Licensee: G?rkem G?ng?r                                  G250104+0003Ac-GEN
#           ggungor@mezun.hacettepe.edu.tr                          CLA105467
#           /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/gamslice.txt
#           node:15017401 v:2
#           Community license for demonstration and instructional purposes only
# Processor information: 1 socket(s), 2 core(s), and 2 thread(s) available
# GAMS 48.5.0   Copyright (C) 1987-2024 GAMS Development. All rights reserved
# --- Starting compilation
# --- MESSAGE_run.gms(65) 2 Mb
# --- . model_setup.gms(66) 2 Mb
# --- .. auxiliary_settings.gms(37) 2 Mb
# --- . model_setup.gms(69) 2 Mb
# --- .. version.gms(23) 2 Mb
# --- . model_setup.gms(70) 2 Mb
# --- .. version_check.gms(7) 2 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_cheap_cfls.gdx
# --- GDX File ($gdxIn) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_cheap_cfls.gdx
# --- .. version_check.gms(24) 3 Mb
# --- . model_setup.gms(73) 3 Mb
# --- .. sets_maps_def.gms(490) 3 Mb
# --- . model_setup.gms(74) 3 Mb
# --- .. parameter_def.gms(878) 3 Mb
# --- . model_setup.gms(77) 3 Mb
# --- .. data_load.gms(9) 3 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_cheap_cfls.gdx
# --- GDX File ($gdxIn) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_cheap_cfls.gdx
# --- .. data_load.gms(111) 3 Mb
# --- ... period_parameter_assignment.gms(118) 3 Mb
# --- .. data_load.gms(252) 3 Mb
# --- . model_setup.gms(80) 3 Mb
# --- .. scaling_investment_costs.gms(182) 3 Mb
# --- . model_setup.gms(86) 3 Mb
# --- .. model_core.gms(2311) 3 Mb
# --- . model_setup.gms(86) 3 Mb
# --- MESSAGE_run.gms(71) 3 Mb
# --- . model_solve.gms(104) 3 Mb
# --- .. aux_computation_time.gms(14) 3 Mb
# --- . model_solve.gms(170) 3 Mb
# --- MESSAGE_run.gms(78) 3 Mb
# --- . reporting.gms(26) 3 Mb
# --- MESSAGE_run.gms(87) 3 Mb
# --- Starting execution: elapsed 0:00:00.044
# --- MESSAGE_run.gms(1600) 4 Mb
#     +++ Importing data from '/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_cheap_cfls.gdx'... +++
# --- MESSAGE_run.gms(1625) 4 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_cheap_cfls.gdx
# --- GDX File (execute_load) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_cheap_cfls.gdx
# --- MESSAGE_run.gms(4481) 4 Mb
#     +++ Solve the perfect-foresight version of MESSAGEix +++
# --- Generating LP model MESSAGE_LP
# --- MESSAGE_run.gms(4499) 5 Mb
# ---   691 rows  566 columns  2,350 non-zeroes
# --- Range statistics (absolute non-zero finite values)
# --- RHS       [min, max] : [ 3.687E-02, 4.450E+01] - Zero values observed as well
# --- Bound     [min, max] : [        NA,        NA] - Zero values observed as well
# --- Matrix    [min, max] : [ 1.000E-01, 4.017E+03]
# --- Executing CPLEX (Solvelink=2): elapsed 0:00:00.054
#
# IBM ILOG CPLEX   48.5.0 5f05ac2f Dec 20, 2024          LEG x86 64bit/Linux
#
# *** This solver runs with a community license. No commercial use.
#
# Reading parameter(s) from "/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/cplex.opt"
# >>  advind = 0
# >>  lpmethod = 4
# >>  threads = 4
# >>  epopt = 1e-06
# Finished reading from "/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 0.06 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 0.64 Mb (peak 0.65 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 22.1.1.0 link memory 0.02 Mb (peak 0.12 Mb)
# --- Starting Cplex
#
# Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_Advance                                 0
# CPXPARAM_LPMethod                                4
# CPXPARAM_Threads                                 4
# CPXPARAM_Parallel                                1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_Barrier_Limits_Iteration                100000000
# CPXPARAM_TimeLimit                               1000000
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   0
# Tried aggregator 1 time.
# LP Presolve eliminated 245 rows and 133 columns.
# Aggregator did 107 substitutions.
# Reduced LP has 338 rows, 371 columns, and 1197 nonzeros.
# Presolve time = 0.00 sec. (0.85 ticks)
# Parallel mode: using up to 4 threads for barrier.
# Number of nonzeros in lower triangle of A*A' = 1087
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.17 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 4
#   Rows in Factor            = 338
#   Integer space required    = 737
#   Total non-zeros in factor = 4033
#   Total FP ops to factor    = 57527
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf Inf Ratio
#    0   2.7275378e+06   2.7469695e+05  7.80e+03  1.14e+02  4.80e+03  1.00e+00
#    1   2.3039490e+06   2.7433178e+05  6.46e+03  9.43e+01  2.52e+03  1.60e-03
#    2   1.7108418e+06   2.8836763e+05  4.54e+03  6.63e+01  1.49e+03  1.30e-03
#    3   1.2751741e+06   3.3278689e+05  3.01e+03  4.40e+01  9.85e+02  1.29e-03
#    4   8.2749196e+05   3.5161975e+05  1.45e+03  2.11e+01  7.55e+02  1.42e-03
#    5   6.3710237e+05   3.8936839e+05  7.90e+02  1.15e+01  2.47e+02  3.30e-03
#    6   5.4186078e+05   4.1553101e+05  4.30e+02  6.28e+00  8.18e+01  8.42e-03
#    7   4.6770378e+05   4.2364926e+05  1.40e+02  2.05e+00  4.10e+01  1.62e-02
#    8   4.4992733e+05   4.3106731e+05  6.67e+01  9.74e-01  1.10e+01  5.80e-02
#    9   4.3804237e+05   4.3250716e+05  2.02e+01  2.95e-01  2.26e+00  1.33e-01
#   10   4.3479736e+05   4.3327269e+05  4.61e+00  6.74e-02  9.60e-01  3.09e-01
#   11   4.3419667e+05   4.3367812e+05  1.70e+00  2.48e-02  2.82e-01  1.12e+00
#   12   4.3388224e+05   4.3377464e+05  2.26e-01  3.30e-03  1.07e-01  2.85e+00
#   13   4.3383543e+05   4.3383452e+05  2.77e-03  4.05e-05  5.72e-04  5.43e+02
#   14   4.3383485e+05   4.3383485e+05  3.54e-07  5.18e-09  6.45e-08  5.08e+06
#   15   4.3383485e+05   4.3383485e+05  8.98e-11  5.40e-13  1.19e-10  4.86e+10
# Barrier time = 0.02 sec. (2.51 ticks)
# Parallel mode: deterministic, using up to 4 threads for concurrent optimization:
#  * Starting dual Simplex on 1 thread...
#  * Starting primal Simplex on 1 thread...
#
# Dual crossover.
#   Dual:  Fixing 178 variables.
#       177 DMoves:  Infeasibility  0.00000000e+00  Objective  4.33834847e+05
#        38 DMoves:  Infeasibility  0.00000000e+00  Objective  4.33834847e+05
#         0 DMoves:  Infeasibility  0.00000000e+00  Objective  4.33834847e+05
#   Dual:  Pushed 35, exchanged 143.
#   Primal:  Fixed no variables.
#
# Dual simplex solved model.
#
# Total crossover time = 0.06 sec. (0.90 ticks)
#
# Total time on 4 threads = 0.08 sec. (4.29 ticks)
#
# --- LP status (1): optimal.
# --- Cplex Time: 0.08sec (det. 4.29 ticks)
#
#
# Optimal solution found
# Objective:       433834.847007
#
# --- Reading solution for model MESSAGE_LP
# --- Executing after solve: elapsed 0:00:00.201
# --- MESSAGE_run.gms(4692) 5 Mb
# --- GDX File (execute_unload) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgOutput_Turkey_energy_model_cheap_cfls.gdx
# --- MESSAGE_run.gms(4694) 5 Mb
#     +++ End of MESSAGEix (stand-alone) run - have a nice day! +++
# *** Status: Normal completion
# --- Job MESSAGE_run.gms Stop 05/04/25 11:58:41 elapsed 0:00:00.208
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# 2025-05-04 11:58:41,894 ERROR at.ac.iiasa.ixmp.objects.Scenario:1691 - variable 'I' not found in gdx!
# 2025-05-04 11:58:41,895 ERROR at.ac.iiasa.ixmp.objects.Scenario:1691 - variable 'C' not found in gdx!
#   node_loc       technology  year_vtg  value    unit
# 0   Turkey  high_efficiency      2020  900.0  USD/kW
# 1   Turkey  high_efficiency      2025  720.0  USD/kW
# 2   Turkey  high_efficiency      2030  540.0  USD/kW
# 3   Turkey  high_efficiency      2035  360.0  USD/kW
# 4   Turkey  high_efficiency      2040  180.0  USD/kW
# 5   Turkey  high_efficiency      2045   90.0  USD/kW
# 6   Turkey  high_efficiency      2050   90.0  USD/kW

# %%
# Prepare a Reporter based on the solved scenario
cfl_rep = Reporter.from_scenario(cfl_scen)
prepare_plots(cfl_rep)

# Run the same reporting on both the base and modified scenarios
for r in base_rep, cfl_rep:
    r.set_filters(t=light_and_appliance)
    r.get("plot new capacity")

# %% [markdown]
# # Exercise: Economic Assumptions
#
# What is the effect of assuming a different interest rate? What if it is higher than the baseline? Lower? How does this affect prices?

# %%
# Show the baseline interest rate
base_scen.par('interestrate')
# Out:
#    year  value unit
# 0  2020    0.1    -
# 1  2025    0.1    -
# 2  2030    0.1    -
# 3  2035    0.1    -
# 4  2040    0.1    -
# 5  2045    0.1    -
# 6  2050    0.1    -

# %%
# Uncomment and complete the following code where "TODO" appears
# with solve_modified(base_scen, new_name="TODO") as econ_scen:
#    # TODO modify the interest rate to a different value

# Cost as a fraction of the baseline cost, due to learning
economy = np.array([1.0, 0.8, 0.6, 0.4, 0.2, 0.1, 0.1])

with solve_modified(base_scen, new_name="economy") as econ_scen:
    # Load the investment cost data (cloned from `base_scen`) for cfl
    data = econ_scen.par("interestrate")
    
    # Reduce the values according to the learning curve
    data["value"] = data["value"] * economy
    
    # Overwrite the values in `cfl_scen` at the same indices
    econ_scen.add_par("interestrate", data)

# Display the new costs
data
# Out:
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# --- Job MESSAGE_run.gms Start 05/04/25 11:59:21 48.5.0 5f05ac2f LEX-LEG x86 64bit/Linux
# --- Applying:
#     /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/gmsprmun.txt
# --- GAMS Parameters defined
#     Input /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/MESSAGE_run.gms
#     ScrDir /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/225a/
#     SysDir /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/
#     LogOption 4
#     --in /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_economy.gdx
#     --out /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgOutput_Turkey_energy_model_economy.gdx
#     --iter /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgIterationReport_Turkey_energy_model_economy.gdx
# Licensee: G?rkem G?ng?r                                  G250104+0003Ac-GEN
#           ggungor@mezun.hacettepe.edu.tr                          CLA105467
#           /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/gamslice.txt
#           node:15017401 v:2
#           Community license for demonstration and instructional purposes only
# Processor information: 1 socket(s), 2 core(s), and 2 thread(s) available
# GAMS 48.5.0   Copyright (C) 1987-2024 GAMS Development. All rights reserved
# --- Starting compilation
# --- MESSAGE_run.gms(65) 2 Mb
# --- . model_setup.gms(66) 2 Mb
# --- .. auxiliary_settings.gms(37) 2 Mb
# --- . model_setup.gms(69) 2 Mb
# --- .. version.gms(23) 2 Mb
# --- . model_setup.gms(70) 2 Mb
# --- .. version_check.gms(7) 2 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_economy.gdx
# --- GDX File ($gdxIn) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_economy.gdx
# --- .. version_check.gms(24) 3 Mb
# --- . model_setup.gms(73) 3 Mb
# --- .. sets_maps_def.gms(490) 3 Mb
# --- . model_setup.gms(74) 3 Mb
# --- .. parameter_def.gms(878) 3 Mb
# --- . model_setup.gms(77) 3 Mb
# --- .. data_load.gms(9) 3 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_economy.gdx
# --- GDX File ($gdxIn) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_economy.gdx
# --- .. data_load.gms(111) 3 Mb
# --- ... period_parameter_assignment.gms(118) 3 Mb
# --- .. data_load.gms(252) 3 Mb
# --- . model_setup.gms(80) 3 Mb
# --- .. scaling_investment_costs.gms(182) 3 Mb
# --- . model_setup.gms(86) 3 Mb
# --- .. model_core.gms(2311) 3 Mb
# --- . model_setup.gms(86) 3 Mb
# --- MESSAGE_run.gms(71) 3 Mb
# --- . model_solve.gms(104) 3 Mb
# --- .. aux_computation_time.gms(14) 3 Mb
# --- . model_solve.gms(170) 3 Mb
# --- MESSAGE_run.gms(78) 3 Mb
# --- . reporting.gms(26) 3 Mb
# --- MESSAGE_run.gms(87) 3 Mb
# --- Starting execution: elapsed 0:00:00.045
# --- MESSAGE_run.gms(1600) 4 Mb
#     +++ Importing data from '/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_economy.gdx'... +++
# --- MESSAGE_run.gms(1625) 4 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_economy.gdx
# --- GDX File (execute_load) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_economy.gdx
# --- MESSAGE_run.gms(4481) 4 Mb
#     +++ Solve the perfect-foresight version of MESSAGEix +++
# --- Generating LP model MESSAGE_LP
# --- MESSAGE_run.gms(4499) 5 Mb
# ---   691 rows  566 columns  2,350 non-zeroes
# --- Range statistics (absolute non-zero finite values)
# --- RHS       [min, max] : [ 3.687E-02, 4.450E+01] - Zero values observed as well
# --- Bound     [min, max] : [        NA,        NA] - Zero values observed as well
# --- Matrix    [min, max] : [ 1.000E-01, 4.017E+03]
# --- Executing CPLEX (Solvelink=2): elapsed 0:00:00.057
#
# IBM ILOG CPLEX   48.5.0 5f05ac2f Dec 20, 2024          LEG x86 64bit/Linux
#
# *** This solver runs with a community license. No commercial use.
#
# Reading parameter(s) from "/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/cplex.opt"
# >>  advind = 0
# >>  lpmethod = 4
# >>  threads = 4
# >>  epopt = 1e-06
# Finished reading from "/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 0.06 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 0.64 Mb (peak 0.65 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 22.1.1.0 link memory 0.02 Mb (peak 0.12 Mb)
# --- Starting Cplex
#
# Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_Advance                                 0
# CPXPARAM_LPMethod                                4
# CPXPARAM_Threads                                 4
# CPXPARAM_Parallel                                1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_Barrier_Limits_Iteration                100000000
# CPXPARAM_TimeLimit                               1000000
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   0
# Tried aggregator 1 time.
# LP Presolve eliminated 245 rows and 133 columns.
# Aggregator did 107 substitutions.
# Reduced LP has 338 rows, 371 columns, and 1197 nonzeros.
# Presolve time = 0.00 sec. (0.85 ticks)
# Parallel mode: using up to 4 threads for barrier.
# Number of nonzeros in lower triangle of A*A' = 1087
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.17 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 4
#   Rows in Factor            = 338
#   Integer space required    = 737
#   Total non-zeros in factor = 4033
#   Total FP ops to factor    = 57527
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf Inf Ratio
#    0   3.6702466e+06   2.4526218e+05  7.80e+03  1.14e+02  3.83e+03  1.00e+00
#    1   3.2964562e+06   2.4349066e+05  6.95e+03  1.02e+02  1.71e+03  1.02e-03
#    2   2.2466622e+06   2.7277052e+05  4.49e+03  6.57e+01  1.12e+03  9.43e-04
#    3   1.5788033e+06   3.4656675e+05  2.79e+03  4.08e+01  7.23e+02  9.44e-04
#    4   1.0484919e+06   3.7789869e+05  1.44e+03  2.10e+01  5.59e+02  1.04e-03
#    5   7.2959184e+05   4.2119791e+05  6.64e+02  9.71e+00  2.52e+02  1.93e-03
#    6   6.3099464e+05   4.5590361e+05  3.93e+02  5.75e+00  1.21e+02  3.67e-03
#    7   5.6780712e+05   4.7326738e+05  2.20e+02  3.22e+00  5.39e+01  8.14e-03
#    8   5.0792560e+05   4.8105441e+05  5.83e+01  8.51e-01  2.20e+01  1.79e-02
#    9   4.9140654e+05   4.8636880e+05  8.04e+00  1.18e-01  6.83e+00  5.86e-02
#   10   4.8968986e+05   4.8799165e+05  3.05e+00  4.46e-02  1.95e+00  2.35e-01
#   11   4.8873193e+05   4.8853322e+05  5.07e-01  7.41e-03  2.71e-02  2.21e+01
#   12   4.8854458e+05   4.8854444e+05  3.60e-04  5.27e-06  2.71e-06  2.66e+04
#   13   4.8854445e+05   4.8854445e+05  4.36e-08  6.38e-10  8.67e-10  3.75e+07
#   14   4.8854445e+05   4.8854445e+05  1.09e-11  1.02e-13  8.77e-11  3.10e+11
# Barrier time = 0.02 sec. (2.37 ticks)
# Parallel mode: deterministic, using up to 4 threads for concurrent optimization:
#  * Starting dual Simplex on 1 thread...
#  * Starting primal Simplex on 1 thread...
#
# Dual crossover.
#   Dual:  Fixing 185 variables.
#       184 DMoves:  Infeasibility  0.00000000e+00  Objective  4.88544454e+05
#        59 DMoves:  Infeasibility  0.00000000e+00  Objective  4.88544454e+05
#         0 DMoves:  Infeasibility  0.00000000e+00  Objective  4.88544454e+05
#   Dual:  Pushed 50, exchanged 135.
#   Primal:  Fixed no variables.
#
# Dual simplex solved model.
#
# Total crossover time = 0.00 sec. (0.88 ticks)
#
# Total time on 4 threads = 0.02 sec. (4.13 ticks)
#
# --- LP status (1): optimal.
# --- Cplex Time: 0.02sec (det. 4.13 ticks)
#
#
# Optimal solution found
# Objective:       488544.453596
#
# --- Reading solution for model MESSAGE_LP
# --- Executing after solve: elapsed 0:00:00.096
# --- MESSAGE_run.gms(4692) 5 Mb
# --- GDX File (execute_unload) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgOutput_Turkey_energy_model_economy.gdx
# --- MESSAGE_run.gms(4694) 5 Mb
#     +++ End of MESSAGEix (stand-alone) run - have a nice day! +++
# *** Status: Normal completion
# --- Job MESSAGE_run.gms Stop 05/04/25 11:59:21 elapsed 0:00:00.122
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# 2025-05-04 11:59:21,583 ERROR at.ac.iiasa.ixmp.objects.Scenario:1691 - variable 'I' not found in gdx!
# 2025-05-04 11:59:21,584 ERROR at.ac.iiasa.ixmp.objects.Scenario:1691 - variable 'C' not found in gdx!
#    year  value unit
# 0  2020   0.10    -
# 1  2025   0.08    -
# 2  2030   0.06    -
# 3  2035   0.04    -
# 4  2040   0.02    -
# 5  2045   0.01    -
# 6  2050   0.01    -

# %%
# TODO based on the examples above, plot (a) new capacity and (b) prices
# Prepare a Reporter based on the solved scenario
econ_rep = Reporter.from_scenario(econ_scen)
prepare_plots(econ_rep)

# Run the same reporting on both the base and modified scenarios
for r in base_rep, econ_rep:
    r.set_filters(t=plants)
    r.get("plot new capacity")

# %%
### Reporting emissions

# %%
from message_ix import Reporter

econ_rep.set_filters(t=plants)
emissions_list = econ_rep.get("emi")
emissions_list
# Out:
# nl      t         yv    ya    m         e    h
# Turkey  coal_ppl  2020  2020  standard  CO2  year    90.363448
#                         2025  standard  CO2  year    90.363448
#                         2030  standard  CO2  year    90.363448
#                         2035  standard  CO2  year    90.363448
#                         2040  standard  CO2  year    90.363448
#                                                        ...
#         oil_ppl   2040  2045  standard  CO2  year     0.000000
#                         2050  standard  CO2  year     0.000000
#                   2045  2045  standard  CO2  year     0.000000
#                         2050  standard  CO2  year     0.000000
#                   2050  2050  standard  CO2  year     0.000000
# Length: 82, dtype: float64, units: tCO2 / kWa

# %%
print(econ_rep.get("EMISS"))
# Out:
# n       e    type_tec  y
# World   CO2  all       2020    114.593167
#                        2025    169.576846
#                        2030    235.077255
#                        2035    253.471258
#                        2040    289.098727
#                        2045    284.109947
#                        2050    270.688212
# Turkey  CO2  all       2020    114.593167
#                        2025    169.576846
#                        2030    235.077255
#                        2035    253.471258
#                        2040    289.098727
#                        2045    284.109947
#                        2050    270.688212
# Name: EMISS, dtype: float64, units: dimensionless

# %% [markdown]
# # Exercise: Carbon Tax
#
# What effect does a carbon tax have on the system? What if it is phased in over time? What is the effect on energy prices?
#
# Hints:
#
# - Which emissions parameters are available from `scenario.par_list()`?
# - Find out which fields are required using `scenario.idx_names(par_name)`
# - Carbon taxes are normally provided in units of USD/tCO2
# - A normal proposed carbon tax is ~30 USD/tCO2

# %%
# Print the names of all parameters that contain "emission"
[name for name in base_scen.par_list() if "emission" in name]
# Out:
# ['bound_emission',
#  'emission_factor',
#  'emission_scaling',
#  'historical_emission',
#  'land_emission',
#  'tax_emission']

# %%
# Print the index names for one of these
base_scen.idx_names("tax_emission")
# Out:
# ['node', 'type_emission', 'type_tec', 'type_year']

# %%
taxes = pd.DataFrame({
    "node": country,
    "type_emission": "GHGs",
    "type_year": horizon,
    "type_tec": "all",
    "value": np.array([0.0, 50.0, 100.0, 150.0, 200.0, 250.0, 300.0]),
    "unit": 'USD/tCO2', 
})

with solve_modified(base_scen, new_name="carbon_tax") as ctax_scen:
    ctax_scen.add_par('tax_emission', taxes)
# Out:
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# --- Job MESSAGE_run.gms Start 05/04/25 12:01:33 48.5.0 5f05ac2f LEX-LEG x86 64bit/Linux
# --- Applying:
#     /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/gmsprmun.txt
# --- GAMS Parameters defined
#     Input /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/MESSAGE_run.gms
#     ScrDir /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/225a/
#     SysDir /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/
#     LogOption 4
#     --in /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_carbon_tax.gdx
#     --out /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgOutput_Turkey_energy_model_carbon_tax.gdx
#     --iter /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgIterationReport_Turkey_energy_model_carbon_tax.gdx
# Licensee: G?rkem G?ng?r                                  G250104+0003Ac-GEN
#           ggungor@mezun.hacettepe.edu.tr                          CLA105467
#           /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/gamslice.txt
#           node:15017401 v:2
#           Community license for demonstration and instructional purposes only
# Processor information: 1 socket(s), 2 core(s), and 2 thread(s) available
# GAMS 48.5.0   Copyright (C) 1987-2024 GAMS Development. All rights reserved
# --- Starting compilation
# --- MESSAGE_run.gms(65) 2 Mb
# --- . model_setup.gms(66) 2 Mb
# --- .. auxiliary_settings.gms(37) 2 Mb
# --- . model_setup.gms(69) 2 Mb
# --- .. version.gms(23) 2 Mb
# --- . model_setup.gms(70) 2 Mb
# --- .. version_check.gms(7) 2 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_carbon_tax.gdx
# --- GDX File ($gdxIn) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_carbon_tax.gdx
# --- .. version_check.gms(24) 3 Mb
# --- . model_setup.gms(73) 3 Mb
# --- .. sets_maps_def.gms(490) 3 Mb
# --- . model_setup.gms(74) 3 Mb
# --- .. parameter_def.gms(878) 3 Mb
# --- . model_setup.gms(77) 3 Mb
# --- .. data_load.gms(9) 3 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_carbon_tax.gdx
# --- GDX File ($gdxIn) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_carbon_tax.gdx
# --- .. data_load.gms(111) 3 Mb
# --- ... period_parameter_assignment.gms(118) 3 Mb
# --- .. data_load.gms(252) 3 Mb
# --- . model_setup.gms(80) 3 Mb
# --- .. scaling_investment_costs.gms(182) 3 Mb
# --- . model_setup.gms(86) 3 Mb
# --- .. model_core.gms(2311) 3 Mb
# --- . model_setup.gms(86) 3 Mb
# --- MESSAGE_run.gms(71) 3 Mb
# --- . model_solve.gms(104) 3 Mb
# --- .. aux_computation_time.gms(14) 3 Mb
# --- . model_solve.gms(170) 3 Mb
# --- MESSAGE_run.gms(78) 3 Mb
# --- . reporting.gms(26) 3 Mb
# --- MESSAGE_run.gms(87) 3 Mb
# --- Starting execution: elapsed 0:00:00.106
# --- MESSAGE_run.gms(1600) 4 Mb
#     +++ Importing data from '/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_carbon_tax.gdx'... +++
# --- MESSAGE_run.gms(1625) 4 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_carbon_tax.gdx
# --- GDX File (execute_load) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_carbon_tax.gdx
# --- MESSAGE_run.gms(4481) 4 Mb
#     +++ Solve the perfect-foresight version of MESSAGEix +++
# --- Generating LP model MESSAGE_LP
# --- MESSAGE_run.gms(4499) 5 Mb
# ---   691 rows  566 columns  2,356 non-zeroes
# --- Range statistics (absolute non-zero finite values)
# --- RHS       [min, max] : [ 3.687E-02, 4.450E+01] - Zero values observed as well
# --- Bound     [min, max] : [        NA,        NA] - Zero values observed as well
# --- Matrix    [min, max] : [ 1.000E-01, 4.017E+03]
# --- Executing CPLEX (Solvelink=2): elapsed 0:00:00.120
#
# IBM ILOG CPLEX   48.5.0 5f05ac2f Dec 20, 2024          LEG x86 64bit/Linux
#
# *** This solver runs with a community license. No commercial use.
#
# Reading parameter(s) from "/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/cplex.opt"
# >>  advind = 0
# >>  lpmethod = 4
# >>  threads = 4
# >>  epopt = 1e-06
# Finished reading from "/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 0.06 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 0.64 Mb (peak 0.65 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 22.1.1.0 link memory 0.02 Mb (peak 0.12 Mb)
# --- Starting Cplex
#
# Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_Advance                                 0
# CPXPARAM_LPMethod                                4
# CPXPARAM_Threads                                 4
# CPXPARAM_Parallel                                1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_Barrier_Limits_Iteration                100000000
# CPXPARAM_TimeLimit                               1000000
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   0
# Tried aggregator 1 time.
# LP Presolve eliminated 245 rows and 133 columns.
# Aggregator did 107 substitutions.
# Reduced LP has 338 rows, 371 columns, and 1197 nonzeros.
# Presolve time = 0.00 sec. (0.85 ticks)
# Parallel mode: using up to 4 threads for barrier.
# Number of nonzeros in lower triangle of A*A' = 1087
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.17 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 4
#   Rows in Factor            = 338
#   Integer space required    = 737
#   Total non-zeros in factor = 4033
#   Total FP ops to factor    = 57527
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf Inf Ratio
#    0   3.7859085e+06   2.7469695e+05  7.80e+03  1.14e+02  4.22e+03  1.00e+00
#    1   3.2921916e+06   2.7158516e+05  6.71e+03  9.80e+01  2.15e+03  1.12e-03
#    2   2.2714593e+06   2.9634608e+05  4.41e+03  6.44e+01  9.56e+02  1.05e-03
#    3   1.5588464e+06   3.4225253e+05  2.68e+03  3.91e+01  6.84e+02  1.02e-03
#    4   1.2849839e+06   3.8141414e+05  2.00e+03  2.92e+01  4.90e+02  1.20e-03
#    5   1.0075388e+06   4.3219235e+05  1.31e+03  1.91e+01  2.47e+02  1.77e-03
#    6   8.4088092e+05   4.7544732e+05  8.64e+02  1.26e+01  1.18e+02  2.70e-03
#    7   7.0059073e+05   5.0460625e+05  4.73e+02  6.91e+00  5.63e+01  4.49e-03
#    8   6.4157449e+05   5.2109478e+05  3.01e+02  4.40e+00  2.86e+01  7.10e-03
#    9   5.8256562e+05   5.3084751e+05  1.28e+02  1.87e+00  1.30e+01  1.26e-02
#   10   5.5538391e+05   5.4124613e+05  3.86e+01  5.63e-01  2.45e+00  6.61e-02
#   11   5.4538140e+05   5.4328656e+05  4.34e+00  6.34e-02  7.07e-01  2.07e-01
#   12   5.4464402e+05   5.4399583e+05  1.60e+00  2.34e-02  1.65e-01  9.20e-01
#   13   5.4431897e+05   5.4411038e+05  4.05e-01  5.92e-03  7.65e-02  1.89e+00
#   14   5.4421149e+05   5.4420790e+05  2.07e-03  3.03e-05  2.31e-03  6.36e+01
#   15   5.4421078e+05   5.4421078e+05  2.86e-07  4.18e-09  3.03e-07  9.03e+05
#   16   5.4421078e+05   5.4421078e+05  6.21e-11  5.54e-13  2.37e-10  1.15e+10
# Barrier time = 0.03 sec. (2.65 ticks)
# Parallel mode: deterministic, using up to 4 threads for concurrent optimization:
#  * Starting dual Simplex on 1 thread...
#  * Starting primal Simplex on 1 thread...
#
# Dual crossover.
#   Dual:  Fixing 167 variables.
#       166 DMoves:  Infeasibility  7.10542736e-14  Objective  5.44210777e+05
#         0 DMoves:  Infeasibility  1.84741111e-13  Objective  5.44210777e+05
#   Dual:  Pushed 62, exchanged 105.
#   Primal:  Fixing 4 variables.
#         3 PMoves:  Infeasibility  2.22044605e-16  Objective  5.44210777e+05
#         0 PMoves:  Infeasibility  2.22044605e-16  Objective  5.44210777e+05
#   Primal:  Pushed 2, exchanged 2.
#
# Dual simplex solved model.
#
# Total crossover time = 0.02 sec. (0.89 ticks)
#
# Total time on 4 threads = 0.06 sec. (4.42 ticks)
#
# --- LP status (1): optimal.
# --- Cplex Time: 0.06sec (det. 4.42 ticks)
#
#
# Optimal solution found
# Objective:       544210.776583
#
# --- Reading solution for model MESSAGE_LP
# --- Executing after solve: elapsed 0:00:00.370
# --- MESSAGE_run.gms(4692) 5 Mb
# --- GDX File (execute_unload) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgOutput_Turkey_energy_model_carbon_tax.gdx
# --- MESSAGE_run.gms(4694) 5 Mb
#     +++ End of MESSAGEix (stand-alone) run - have a nice day! +++
# *** Status: Normal completion
# --- Job MESSAGE_run.gms Stop 05/04/25 12:01:34 elapsed 0:00:00.394
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# 2025-05-04 12:01:34,114 ERROR at.ac.iiasa.ixmp.objects.Scenario:1691 - variable 'I' not found in gdx!
# 2025-05-04 12:01:34,115 ERROR at.ac.iiasa.ixmp.objects.Scenario:1691 - variable 'C' not found in gdx!

# %%
# Prepare a Reporter based on the solved scenario
ctax_rep = Reporter.from_scenario(ctax_scen)
prepare_plots(ctax_rep)

# Run the same reporting on both the base and modified scenarios
for r in base_rep, ctax_rep:
    r.set_filters(t=plants, c=None)
    r.get("plot new capacity")
    r.get("plot capacity")
    r.get("plot activity")
    r.set_filters(t=None, c=["hvac", "light_and_appliance"])
    r.get("plot prices")

# %%
print(ctax_rep.get("EMISS"))
# Out:
# n       e    type_tec  y
# World   CO2  all       2020    114.593167
#                        2025    109.569513
#                        2030     75.138000
#                        2035     59.956755
#                        2040     40.323865
#                        2045      0.765997
#                        2050      0.000000
# Turkey  CO2  all       2020    114.593167
#                        2025    109.569513
#                        2030     75.138000
#                        2035     59.956755
#                        2040     40.323865
#                        2045      0.765997
#                        2050      0.000000
# Name: EMISS, dtype: float64, units: dimensionless

# %% [markdown]
# # Exercise: Emissions constraint

# %%
# Print the index names for one of these
base_scen.idx_names("bound_emission")
# Out:
# ['node', 'type_emission', 'type_tec', 'type_year']

# %%
bounds = pd.DataFrame({
    "node": country,
    "type_emission": "GHGs",
    "type_year": horizon,
    "type_tec": "all",
    "value": np.array([114.593167, 109.569513, 75.138000, 59.956755, 40.323865, 0.765997, 0.000000]),
    "unit": 'tCO2', 
})

with solve_modified(base_scen, new_name="emissions_constraint") as emissions_scen:
    emissions_scen.add_par('bound_emission', bounds)
# Out:
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# --- Job MESSAGE_run.gms Start 05/04/25 12:11:38 48.5.0 5f05ac2f LEX-LEG x86 64bit/Linux
# --- Applying:
#     /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/gmsprmun.txt
# --- GAMS Parameters defined
#     Input /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/MESSAGE_run.gms
#     ScrDir /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/225a/
#     SysDir /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/
#     LogOption 4
#     --in /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_emissions_constraint.gdx
#     --out /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgOutput_Turkey_energy_model_emissions_constraint.gdx
#     --iter /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgIterationReport_Turkey_energy_model_emissions_constraint.gdx
# Licensee: G?rkem G?ng?r                                  G250104+0003Ac-GEN
#           ggungor@mezun.hacettepe.edu.tr                          CLA105467
#           /home/ggungor/Downloads/gams48.5_linux_x64_64_sfx/gamslice.txt
#           node:15017401 v:2
#           Community license for demonstration and instructional purposes only
# Processor information: 1 socket(s), 2 core(s), and 2 thread(s) available
# GAMS 48.5.0   Copyright (C) 1987-2024 GAMS Development. All rights reserved
# --- Starting compilation
# --- MESSAGE_run.gms(65) 2 Mb
# --- . model_setup.gms(66) 2 Mb
# --- .. auxiliary_settings.gms(37) 2 Mb
# --- . model_setup.gms(69) 2 Mb
# --- .. version.gms(23) 2 Mb
# --- . model_setup.gms(70) 2 Mb
# --- .. version_check.gms(7) 2 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_emissions_constraint.gdx
# --- GDX File ($gdxIn) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_emissions_constraint.gdx
# --- .. version_check.gms(24) 3 Mb
# --- . model_setup.gms(73) 3 Mb
# --- .. sets_maps_def.gms(490) 3 Mb
# --- . model_setup.gms(74) 3 Mb
# --- .. parameter_def.gms(878) 3 Mb
# --- . model_setup.gms(77) 3 Mb
# --- .. data_load.gms(9) 3 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_emissions_constraint.gdx
# --- GDX File ($gdxIn) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_emissions_constraint.gdx
# --- .. data_load.gms(111) 3 Mb
# --- ... period_parameter_assignment.gms(118) 3 Mb
# --- .. data_load.gms(252) 3 Mb
# --- . model_setup.gms(80) 3 Mb
# --- .. scaling_investment_costs.gms(182) 3 Mb
# --- . model_setup.gms(86) 3 Mb
# --- .. model_core.gms(2311) 3 Mb
# --- . model_setup.gms(86) 3 Mb
# --- MESSAGE_run.gms(71) 3 Mb
# --- . model_solve.gms(104) 3 Mb
# --- .. aux_computation_time.gms(14) 3 Mb
# --- . model_solve.gms(170) 3 Mb
# --- MESSAGE_run.gms(78) 3 Mb
# --- . reporting.gms(26) 3 Mb
# --- MESSAGE_run.gms(87) 3 Mb
# --- Starting execution: elapsed 0:00:00.206
# --- MESSAGE_run.gms(1600) 4 Mb
#     +++ Importing data from '/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_emissions_constraint.gdx'... +++
# --- MESSAGE_run.gms(1625) 4 Mb
# --- GDXin=/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_emissions_constraint.gdx
# --- GDX File (execute_load) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/data/MsgData_Turkey_energy_model_emissions_constraint.gdx
# --- MESSAGE_run.gms(4481) 4 Mb
#     +++ Solve the perfect-foresight version of MESSAGEix +++
# --- Generating LP model MESSAGE_LP
# --- MESSAGE_run.gms(4499) 5 Mb
# ---   698 rows  566 columns  2,357 non-zeroes
# --- Range statistics (absolute non-zero finite values)
# --- RHS       [min, max] : [ 3.687E-02, 1.146E+02] - Zero values observed as well
# --- Bound     [min, max] : [        NA,        NA] - Zero values observed as well
# --- Matrix    [min, max] : [ 1.000E-01, 4.017E+03]
# --- Executing CPLEX (Solvelink=2): elapsed 0:00:00.271
#
# IBM ILOG CPLEX   48.5.0 5f05ac2f Dec 20, 2024          LEG x86 64bit/Linux
#
# *** This solver runs with a community license. No commercial use.
#
# Reading parameter(s) from "/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/cplex.opt"
# >>  advind = 0
# >>  lpmethod = 4
# >>  threads = 4
# >>  epopt = 1e-06
# Finished reading from "/home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/cplex.opt"
#
# --- GMO setup time: 0.00s
# --- Space for names approximately 0.06 Mb
# --- Use option 'names no' to turn use of names off
# --- GMO memory 0.64 Mb (peak 0.65 Mb)
# --- Dictionary memory 0.00 Mb
# --- Cplex 22.1.1.0 link memory 0.02 Mb (peak 0.12 Mb)
# --- Starting Cplex
#
# Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_Advance                                 0
# CPXPARAM_LPMethod                                4
# CPXPARAM_Threads                                 4
# CPXPARAM_Parallel                                1
# CPXPARAM_MIP_Display                             4
# CPXPARAM_MIP_Pool_Capacity                       0
# CPXPARAM_Barrier_Limits_Iteration                100000000
# CPXPARAM_TimeLimit                               1000000
# CPXPARAM_MIP_Tolerances_AbsMIPGap                0
# CPXPARAM_MIP_Tolerances_MIPGap                   0
# Tried aggregator 1 time.
# LP Presolve eliminated 285 rows and 171 columns.
# Aggregator did 101 substitutions.
# Reduced LP has 311 rows, 336 columns, and 1140 nonzeros.
# Presolve time = 0.01 sec. (0.84 ticks)
# Parallel mode: using up to 4 threads for barrier.
# Number of nonzeros in lower triangle of A*A' = 1072
# Using Approximate Minimum Degree ordering
# Total time for automatic ordering = 0.00 sec. (0.15 ticks)
# Summary statistics for Cholesky factor:
#   Threads                   = 4
#   Rows in Factor            = 311
#   Integer space required    = 681
#   Total non-zeros in factor = 3964
#   Total FP ops to factor    = 59302
#  Itn      Primal Obj        Dual Obj  Prim Inf Upper Inf  Dual Inf Inf Ratio
#    0   2.9116088e+06   2.7469695e+05  7.58e+03  1.14e+02  4.37e+03  1.00e+00
#    1   2.5008706e+06   2.7173317e+05  6.40e+03  9.63e+01  2.08e+03  1.25e-03
#    2   1.7653372e+06   2.9498283e+05  4.25e+03  6.39e+01  9.93e+02  1.18e-03
#    3   1.2789387e+06   3.3804465e+05  2.67e+03  4.02e+01  7.26e+02  1.13e-03
#    4   9.9393490e+05   3.6055249e+05  1.78e+03  2.68e+01  5.38e+02  1.30e-03
#    5   7.1919992e+05   3.9969302e+05  9.25e+02  1.39e+01  1.98e+02  2.26e-03
#    6   6.3732056e+05   4.2874843e+05  6.11e+02  9.20e+00  1.24e+02  2.96e-03
#    7   5.6937310e+05   4.5162834e+05  3.42e+02  5.15e+00  7.19e+01  4.37e-03
#    8   5.1814090e+05   4.6384834e+05  1.46e+02  2.20e+00  4.09e+01  6.98e-03
#    9   4.9358931e+05   4.7683194e+05  3.88e+01  5.84e-01  1.54e+01  1.85e-02
#   10   4.8783655e+05   4.8228556e+05  1.11e+01  1.67e-01  5.77e+00  5.17e-02
#   11   4.8576260e+05   4.8445041e+05  2.14e+00  3.23e-02  1.58e+00  2.18e-01
#   12   4.8519681e+05   4.8518006e+05  2.90e-02  4.36e-04  1.91e-02  2.84e+01
#   13   4.8518652e+05   4.8518652e+05  6.13e-06  9.23e-08  2.63e-06  2.02e+05
#   14   4.8518652e+05   4.8518652e+05  2.87e-06  6.99e-09  2.33e-05  2.79e+07
# Barrier time = 0.03 sec. (2.18 ticks)
# Parallel mode: deterministic, using up to 4 threads for concurrent optimization:
#  * Starting dual Simplex on 1 thread...
#  * Starting primal Simplex on 1 thread...
#
# Dual crossover.
#   Dual:  Fixing 145 variables.
#       144 DMoves:  Infeasibility  1.13686838e-13  Objective  4.85186518e+05
#        19 DMoves:  Infeasibility  0.00000000e+00  Objective  4.85186518e+05
#         0 DMoves:  Infeasibility  0.00000000e+00  Objective  4.85186518e+05
#   Dual:  Pushed 40, exchanged 105.
#   Primal:  Fixing 4 variables.
#         3 PMoves:  Infeasibility  5.96084562e-08  Objective  4.85186518e+05
#         0 PMoves:  Infeasibility  5.96084562e-08  Objective  4.85186518e+05
#   Primal:  Pushed 2, exchanged 2.
#
# Dual simplex solved model.
#
# Total crossover time = 0.07 sec. (0.96 ticks)
#
# Total time on 4 threads = 0.10 sec. (4.01 ticks)
#
# --- LP status (1): optimal.
# --- Cplex Time: 0.11sec (det. 4.01 ticks)
#
#
# Optimal solution found
# Objective:       485186.518302
#
# --- Reading solution for model MESSAGE_LP
# --- Executing after solve: elapsed 0:00:00.633
# --- MESSAGE_run.gms(4692) 5 Mb
# --- GDX File (execute_unload) /home/ggungor/miniconda3/envs/message_env/lib/python3.8/site-packages/message_ix/model/output/MsgOutput_Turkey_energy_model_emissions_constraint.gdx
# --- MESSAGE_run.gms(4694) 5 Mb
#     +++ End of MESSAGEix (stand-alone) run - have a nice day! +++
# *** Status: Normal completion
# --- Job MESSAGE_run.gms Stop 05/04/25 12:11:39 elapsed 0:00:00.644
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# --- Warning: The GAMS version [48.5.0] differs from the API version [24.8.3].
# 2025-05-04 12:11:39,184 ERROR at.ac.iiasa.ixmp.objects.Scenario:1691 - variable 'I' not found in gdx!
# 2025-05-04 12:11:39,185 ERROR at.ac.iiasa.ixmp.objects.Scenario:1691 - variable 'C' not found in gdx!

# %%
# Prepare a Reporter based on the solved scenario
emissions_rep = Reporter.from_scenario(emissions_scen)
prepare_plots(emissions_rep)

# Run the same reporting on both the base and modified scenarios
for r in ctax_rep, emissions_rep:
    r.set_filters(t=plants, c=None)
    r.get("plot new capacity")
    r.get("plot capacity")
    r.get("plot activity")
    r.set_filters(t=None, c=["hvac", "light_and_appliance"])
    r.get("plot prices")

# %%
mp.close_db()
